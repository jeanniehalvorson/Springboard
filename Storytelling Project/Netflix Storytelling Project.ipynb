# %% [markdown]
# # Netflix Top 10 Analysis: Insights and Trends

# %% [markdown]
# ### Understanding Netflix's Popularity Trends
#
# In today's digital age, streaming services have revolutionized the way we consume entertainment. Among these, Netflix stands out as a global leader, constantly innovating and adapting to viewer preferences. To stay ahead in the competitive streaming landscape, it’s crucial for Netflix to understand what content resonates most with its audience. This is where our analysis comes into play.
#
# ### Dataset Overview
# We delved into the Netflix Daily Top 10 dataset, which chronicles the daily rankings of the top 10 movies and TV shows in the United States from 2020 to March 2022. This dataset includes several key attributes such as:
#
#     * Rank: The position of the title on a given day.
#     * Title: The name of the movie or TV show.
#     * Type: Classification as a movie or TV show.
#     * Netflix Exclusive: Indicator if the title is a Netflix Original.
#     * Netflix Release Date: The date the title was released on Netflix.
#     * Days in Top 10: The number of days a title has remained in the top 10.
#     * Viewership Score: A metric representing the popularity of the title.
#
# ### Purpose of the Analysis
#
# Our primary objective is to uncover insights into the viewership patterns and trends that define the most popular content on Netflix. By analyzing these trends, we aim to answer several pivotal questions:
#
#     * What types of content dominate the top ranks on Netflix?
#     * How do viewership scores vary over time and across different titles?
#     * Are Netflix Originals more successful in maintaining viewer interest?
#     * What patterns can we observe in the longevity of titles within the top 10 rankings?
#
# ### Importance for Netflix
# Understanding these trends is not just an academic exercise but a strategic necessity. Insights drawn from this analysis can help Netflix:
#
#     * Enhance Content Strategy: By identifying what types of content (movies vs. TV shows, genres, etc.) are most successful, Netflix can tailor its production and acquisition strategies to better meet viewer demands.
#     * Improve Viewer Retention: By recognizing patterns in viewer engagement, Netflix can make data-driven decisions to promote content that keeps subscribers engaged for longer periods.
#     * Optimize Release Schedules: By understanding the timing and impact of new releases, Netflix can strategically plan the launch of new content to maximize viewership and subscriber growth.
#
# ### Structure of the Presentation
# In the following sections, we will present our key findings through a series of visualizations and narratives that highlight the most compelling trends from the dataset. We will explore:
#
#     * Trends in top-ranked titles over time.
#     * Distribution and variability in viewership scores.
#     * Comparison of the longevity of movies versus TV shows in the top 10.
#     * The dominance of Netflix Originals in the rankings.
#
# By the end of this presentation, we aim to provide a clear picture of what makes content successful on Netflix and how these insights can be leveraged for future growth.

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("netflix daily top 10.csv")

# %%
print(df.columns)
# Out:
# Index(['As of', 'Rank', 'Year to Date Rank', 'Last Week Rank', 'Title', 'Type',
#        'Netflix Exclusive', 'Netflix Release Date', 'Days In Top 10',
#        'Viewership Score'],
#       dtype='object')

# %%
print(df.describe())
# Out:
#               Rank  Days In Top 10  Viewership Score
# count  7100.000000     7100.000000       7100.000000
# mean      5.500000       24.123662        122.790141
# std       2.872484       58.473789        213.861642
# min       1.000000        1.000000          1.000000
# 25%       3.000000        3.000000         19.000000
# 50%       5.500000        7.000000         50.000000
# 75%       8.000000       18.000000        128.000000
# max      10.000000      428.000000       1474.000000

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7100 entries, 0 to 7099
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   As of                 7100 non-null   object
#  1   Rank                  7100 non-null   int64
#  2   Year to Date Rank     7100 non-null   object
#  3   Last Week Rank        7100 non-null   object
#  4   Title                 7100 non-null   object
#  5   Type                  7100 non-null   object
#  6   Netflix Exclusive     4599 non-null   object
#  7   Netflix Release Date  7100 non-null   object
#  8   Days In Top 10        7100 non-null   int64
#  9   Viewership Score      7100 non-null   int64
# dtypes: int64(3), object(7)
# memory usage: 554.8+ KB
# None

# %% [markdown]
# ## 1. Trend of Top-Ranked Titles Over Time

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Convert 'As of' to datetime
df['As of'] = pd.to_datetime(df['As of'])

# Filter for the top-ranked title (Rank 1)
top_ranked = df[df['Rank'] == 1]

plt.figure(figsize=(12, 6))
sns.lineplot(x='As of', y='Viewership Score', data=top_ranked, marker='o')
plt.title('Trend of Viewership Score of Top-Ranked Titles Over Time')
plt.xlabel('Date')
plt.ylabel('Viewership Score')
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ## 2. Distribution of Viewership Scores

# %%
plt.figure(figsize=(12, 6))
sns.histplot(df['Viewership Score'], bins=30, kde=True)
plt.title('Distribution of Viewership Scores')
plt.xlabel('Viewership Score')
plt.ylabel('Frequency')
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ## 3. Days in Top 10 by Type (Movie/TV Show)

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x='Type', y='Days In Top 10', data=df)
plt.title('Average Number of Days in Top 10 by Type')
plt.xlabel('Type')
plt.ylabel('Average Days in Top 10')
plt.show()

# %% [markdown]
# ## 4. Top Titles by Viewership Score

# %%
df['Title'] = df['Title'].replace({'The Queenâ\x80\x99s Gambit': 'The Queen\'s Gambit'})
top_titles = df.groupby('Title')['Viewership Score'].max().sort_values(ascending=False).head(10)


plt.figure(figsize=(12, 6))
sns.barplot(x=top_titles.values, y=top_titles.index, palette='viridis')
plt.title('Top 10 Titles by Viewership Score')
plt.xlabel('Viewership Score')
plt.ylabel('Title')
plt.show()

# %% [markdown]
# ### Key Findings:
#
# ### Top-Ranked Titles Over Time:
# The viewership scores for top-ranked titles have shown significant variability. Notably, spikes in viewership often coincide with the release of highly anticipated series or movies.
#
# #### Viewership Score Distribution:
# Most titles have viewership scores below 200, but a few outliers have exceptionally high scores, indicating massive popularity.
#
# #### Average Days in Top 10 by Type:
# On average, TV shows stay in the top 10 longer than movies. This suggests that series tend to maintain viewer interest over extended periods compared to films.
#
# #### Top Titles by Viewership Score:
# The titles with the highest viewership scores are predominantly Netflix Originals, highlighting the success of Netflix’s exclusive content strategy.

# %% [markdown]
# ## Conclusion
#
# ### Key Takeaways
# Our in-depth analysis of the Netflix Daily Top 10 dataset has provided valuable insights into the viewing preferences and patterns of Netflix users in the United States from 2020 to March 2022. Here are the key takeaways:
#
# #### Dominance of Netflix Originals:
# Our findings highlight that Netflix Originals consistently secure high ranks and achieve impressive viewership scores. This underscores the success of Netflix’s strategy to invest in exclusive content, which not only attracts viewers but also retains them.
#
# #### Viewership Score Variability:
# The distribution of viewership scores reveals a broad spectrum of popularity, with a few titles achieving exceptionally high scores. This variability suggests that while most content garners moderate attention, breakout hits can significantly drive overall viewership.
#
# #### Longevity in the Top 10:
# TV shows, particularly series, tend to remain in the top 10 for longer durations compared to movies. This indicates that episodic content has a greater potential for sustained viewer engagement, likely due to the continuous storyline that keeps viewers coming back for more.
#
#
#
# Overall, these insights are crucial for Netflix as they highlight the importance of original content and the significant role of TV series in maintaining viewer interest. By leveraging these findings, Netflix can further refine its content strategy, focusing on producing and promoting content that resonates most with its audience. This strategic focus will help Netflix continue to dominate the streaming industry, ensuring long-term growth and subscriber satisfaction. As the streaming landscape evolves, such data-driven insights will remain indispensable in guiding Netflix’s content decisions and maintaining its leadership position.
